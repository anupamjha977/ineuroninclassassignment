# %%
import pandas as pd

# %%
df=pd.read_excel("AgentPerformance.xlsx")

# %%
df1=pd.read_excel(r"C:\Users\Lenovo\Downloads\Agent_Login_Report.xls")

# %%
df
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1  2022-07-30        Prerna Singh           11
# 1         2  2022-07-30       Nandani Gupta           11
# 2         3  2022-07-30          Ameya Jain           14
# 3         4  2022-07-30       Mahesh Sarade           14
# 4         5  2022-07-30              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  2022-07-01   Sowmiya Sivakumar            0
# 2156   2157  2022-07-01             Nitin M            0
# 2157   2158  2022-07-01              Vivek             0
# 2158   2159  2022-07-01       Ayushi Mishra            0
# 2159   2160  2022-07-01  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# ...

# %%
df1
# Out:
#      Agent Login Report          Unnamed: 1 Unnamed: 2   Unnamed: 3  \
# 0                   NaN                 NaN        NaN          NaN
# 1                 SL No               Agent       Date   Login Time
# 2                     1  Shivananda Sonwane  30-Jul-22  03:35:29 PM
# 3                     2      Khushboo Priya  30-Jul-22  03:06:59 PM
# 4                     3       Nandani Gupta  30-Jul-22  03:04:24 PM
# ...                 ...                 ...        ...          ...
# 997                 996        Manjunatha A  20-Jul-22  09:03:51 AM
# 998                 997            Bharath   20-Jul-22  09:00:49 AM
# 999                 998      Khushboo Priya  20-Jul-22  08:59:20 AM
# 1000                999        Nishtha Jain  20-Jul-22  08:43:55 AM
# 1001               1000              Tarun   01-Jul-22  01:52:47 AM
#
#        Unnamed: 4 Unnamed: 5
# 0             NaN        NaN
# 1     Logout Time   Duration
# 2     05:39:39 PM   02:04:10
# 3     03:07:16 PM   00:00:17
# ...

# %%
df.isna()
# Out:
#       SL No   Date  Agent Name  Total Chats  Average Response Time  \
# 0     False  False       False        False                  False
# 1     False  False       False        False                  False
# 2     False  False       False        False                  False
# 3     False  False       False        False                  False
# 4     False  False       False        False                  False
# ...     ...    ...         ...          ...                    ...
# 2155  False  False       False        False                  False
# 2156  False  False       False        False                  False
# 2157  False  False       False        False                  False
# 2158  False  False       False        False                  False
# 2159  False  False       False        False                  False
#
#       Average Resolution Time  Average Rating  Total Feedback
# 0                       False           False           False
# ...

# %%
df1.isna
# Out:
# <bound method DataFrame.isna of      Agent Login Report          Unnamed: 1 Unnamed: 2   Unnamed: 3  \
# 0                   NaN                 NaN        NaN          NaN
# 1                 SL No               Agent       Date   Login Time
# 2                     1  Shivananda Sonwane  30-Jul-22  03:35:29 PM
# 3                     2      Khushboo Priya  30-Jul-22  03:06:59 PM
# 4                     3       Nandani Gupta  30-Jul-22  03:04:24 PM
# ...                 ...                 ...        ...          ...
# 997                 996        Manjunatha A  20-Jul-22  09:03:51 AM
# 998                 997            Bharath   20-Jul-22  09:00:49 AM
# 999                 998      Khushboo Priya  20-Jul-22  08:59:20 AM
# 1000                999        Nishtha Jain  20-Jul-22  08:43:55 AM
# 1001               1000              Tarun   01-Jul-22  01:52:47 AM
#
#        Unnamed: 4 Unnamed: 5
# 0             NaN        NaN
# 1     Logout Time   Duration
# ...

# %%
#change header to secondrow for  agent login report
df1=pd.read_excel(r"C:\Users\Lenovo\Downloads\Agent_Login_Report.xls",header=2)

# %%
df1
# Out:
#      SL No               Agent       Date   Login Time  Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM   02:04:10
# 1        2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM   00:00:17
# 2        3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM   00:45:06
# 4        5             Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM   01:08:36
# ..     ...                 ...        ...          ...          ...        ...
# 995    996        Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM   05:58:37
# 996    997            Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM   06:00:43
# 997    998      Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM   05:27:34
# 998    999        Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM   05:16:38
# 999   1000              Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM  514:08:20
#
# [1000 rows x 6 columns]

# %%
df.dtypes
# Out:
# SL No                        int64
# Date                        object
# Agent Name                  object
# Total Chats                  int64
# Average Response Time       object
# Average Resolution Time     object
# Average Rating             float64
# Total Feedback               int64
# dtype: object

# %%
#convert Date type
df["Converted_date"]=pd.to_datetime(df["Date"])
df
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1  2022-07-30        Prerna Singh           11
# 1         2  2022-07-30       Nandani Gupta           11
# 2         3  2022-07-30          Ameya Jain           14
# 3         4  2022-07-30       Mahesh Sarade           14
# 4         5  2022-07-30              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  2022-07-01   Sowmiya Sivakumar            0
# 2156   2157  2022-07-01             Nitin M            0
# 2157   2158  2022-07-01              Vivek             0
# 2158   2159  2022-07-01       Ayushi Mishra            0
# 2159   2160  2022-07-01  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# ...

# %%
df["Converted_Date_Week"]=df["Converted_date"].dt.week
df
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_15900/3240736391.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df["Converted_Date_Week"]=df["Converted_date"].dt.week
#       SL No        Date          Agent Name  Total Chats  \
# 0         1  2022-07-30        Prerna Singh           11
# 1         2  2022-07-30       Nandani Gupta           11
# 2         3  2022-07-30          Ameya Jain           14
# 3         4  2022-07-30       Mahesh Sarade           14
# 4         5  2022-07-30              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  2022-07-01   Sowmiya Sivakumar            0
# 2156   2157  2022-07-01             Nitin M            0
# 2157   2158  2022-07-01              Vivek             0
# 2158   2159  2022-07-01       Ayushi Mishra            0
# 2159   2160  2022-07-01  Chaitra K Hiremath            0
#
# ...

# %%
df.drop(df[df['Total Chats']==0].index,axis=0,inplace=True) #when total chat is 0 then agent as every other column is 0

# %%
ser1=df.groupby(['Agent Name','Converted_Date_Week'])['Average Rating'].mean()

# %%
agent_weekly_rating=ser1.to_frame()
agent_weekly_rating.head(100)
# Out:
#                                    Average Rating
# Agent Name    Converted_Date_Week
# Aditya Shinde 26                         3.850000
#               27                         4.516000
#               28                         4.746000
# Aditya_iot    27                         4.315000
#               28                         4.100000
# ...                                           ...
# Manjunatha A  30                         4.182500
# Mithun S      27                         2.286667
#               28                         4.346000
#               29                         4.344000
#               30                         4.092000
#
# [100 rows x 1 columns]

# %%
df["Converted_Day"]=df["Converted_date"].dt.day

# %%
df
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1  2022-07-30        Prerna Singh           11
# 1         2  2022-07-30       Nandani Gupta           11
# 2         3  2022-07-30          Ameya Jain           14
# 3         4  2022-07-30       Mahesh Sarade           14
# 4         5  2022-07-30              Swati            14
# ...     ...         ...                 ...          ...
# 2101   2102  2022-07-01       Jaydeep Dixit           25
# 2102   2103  2022-07-01  Shivananda Sonwane           23
# 2103   2104  2022-07-01      Khushboo Priya           24
# 2104   2105  2022-07-01     Hrisikesh Neogi           15
# 2105   2106  2022-07-01              Tarun            22
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# ...

# %%
question2=df.groupby("Agent Name")["Converted_Day"].count()

# %%
totalagentday=question2.to_frame()
pd.set_option('display.max_rows', None)
totalagentday
# Out:
#                         Converted_Day
# Agent Name
# Aditya Shinde                      12
# Aditya_iot                         17
# Ameya Jain                         15
# Anirudh                             7
# Ankitjha                            3
# Anurag Tiwari                       2
# Aravind                            14
# Ashad Nasim                         2
# Ayushi Mishra                      24
# Bharath                            19
# Boktiar Ahmed Bappy                26
# Chaitra K Hiremath                  6
# Deepranjan Gupta                   21
# Dibyanshu                           1
# Harikrishnan Shaji                 19
# Hitesh Choudhary                    1
# Hrisikesh Neogi                    21
# Ishawant Kumar                     24
# Jawala Prakash                     25
# Jayant Kumar                        8
# Jaydeep Dixit                      21
# Khushboo Priya                     26
# Madhulika G                        24
# ...

# %%
#to find the total query taken we will sum the total chat
question3=df.groupby("Agent Name")["Total Chats"].sum()
totalquery=question3.to_frame()
totalquery
# Out:
#                         Total Chats
# Agent Name
# Aditya Shinde                   277
# Aditya_iot                      231
# Ameya Jain                      322
# Anirudh                          81
# Ankitjha                          5
# Anurag Tiwari                     4
# Aravind                         366
# Ashad Nasim                      18
# Ayushi Mishra                   514
# Bharath                         369
# Boktiar Ahmed Bappy             452
# Chaitra K Hiremath               64
# Deepranjan Gupta                493
# Dibyanshu                         1
# Harikrishnan Shaji              381
# Hitesh Choudhary                  1
# Hrisikesh Neogi                 578
# Ishawant Kumar                  338
# Jawala Prakash                  439
# Jayant Kumar                    127
# Jaydeep Dixit                   512
# Khushboo Priya                  446
# Madhulika G                     469
# Mahak                             7
# ...

# %%
#to find the total feedback taken we will sum the total chat
question4=df.groupby("Agent Name")["Total Feedback"].sum()
totalfeedback=question4.to_frame()
totalfeedback
# Out:
#                         Total Feedback
# Agent Name
# Aditya Shinde                      153
# Aditya_iot                         131
# Ameya Jain                         228
# Anirudh                             39
# Ankitjha                             3
# Anurag Tiwari                        3
# Aravind                            233
# Ashad Nasim                          9
# Ayushi Mishra                      329
# Bharath                            247
# Boktiar Ahmed Bappy                311
# Chaitra K Hiremath                  37
# Deepranjan Gupta                   312
# Dibyanshu                            0
# Harikrishnan Shaji                 231
# Hitesh Choudhary                     0
# Hrisikesh Neogi                    367
# Ishawant Kumar                     202
# Jawala Prakash                     250
# Jayant Kumar                        70
# Jaydeep Dixit                      305
# Khushboo Priya                     289
# Madhulika G                        281
# ...

# %%
question5=df[(df["Average Rating"]>=3.5)&(df["Average Rating"]<4)]
rating=question5["Agent Name"].unique()
pd.DataFrame(rating,columns=["Agent Name"])
# Out:
#              Agent Name
# 0                Swati
# 1          Manjunatha A
# 2         Prateek _iot
# 3         Nandani Gupta
# 4         Jaydeep Dixit
# 5         Mahesh Sarade
# 6              Zeeshan
# 7       Hrisikesh Neogi
# 8        Khushboo Priya
# 9                Wasim
# 10       Jawala Prakash
# 11         Nishtha Jain
# 12         Prerna Singh
# 13  Boktiar Ahmed Bappy
# 14          Muskan Garg
# 15   Harikrishnan Shaji
# 16     Deepranjan Gupta
# 17             Shivan K
# 18          Madhulika G
# 19          Rishav Dash
# 20              Maitry
# 21             Mithun S
# 22          Aditya_iot
# 23       Ishawant Kumar
# 24        Ayushi Mishra
# 25   Shivananda Sonwane
# 26        Sandipan Saha
# 27             Anirudh
# 28         Jayant Kumar
# 29        Anurag Tiwari
# 30       Saurabh Shukla
# 31        Aditya Shinde

# %%
question6=df[df["Average Rating"]<3.5]
rating=question6["Agent Name"].unique()
pd.DataFrame(rating,columns=["Agent Name"])
# Out:
#              Agent Name
# 0         Nandani Gupta
# 1        Jawala Prakash
# 2     Sowmiya Sivakumar
# 3      Shiva Srivastava
# 4           Aditya_iot
# 5          Nishtha Jain
# 6   Boktiar Ahmed Bappy
# 7             Ankitjha
# 8    Chaitra K Hiremath
# 9              Mithun S
# 10       Ishawant Kumar
# 11     Deepranjan Gupta
# 12        Ayushi Mishra
# 13     Hitesh Choudhary
# 14          Rishav Dash
# 15               Vivek
# 16        Mahesh Sarade
# 17   Harikrishnan Shaji
# 18             Anirudh
# 19          Mukesh Rao
# 20         Jayant Kumar
# 21        Sanjeev Kumar
# 22        Anurag Tiwari
# 23             Maneesh
# 24        Prateek _iot
# 25           Dibyanshu
# 26             Shivan K
# 27         Manjunatha A
# 28          Ashad Nasim
# 29       Khushboo Priya
# 30               Mahak
# 31             Samprit
# 32   Shivananda Sonwane
# 33         Prerna Singh
# 34       Saurabh Shukla
# 35               Tarun

# %%
question7=df[df["Average Rating"]>4]
rating=question7["Agent Name"].unique()
pd.DataFrame(rating,columns=["Agent Name"])
# Out:
#                 Agent Name
# 0             Prerna Singh
# 1               Ameya Jain
# 2            Mahesh Sarade
# 3                  Mukesh
# 4          Saikumarreddy N
# 5            Sanjeev Kumar
# 6           Shubham Sharma
# 7             Nishtha Jain
# 8           Khushboo Priya
# 9            Suraj S Bilgi
# 10      Harikrishnan Shaji
# 11         Hrisikesh Neogi
# 12                Shivan K
# 13       Sowmiya Sivakumar
# 14             Madhulika G
# 15                Mithun S
# 16     Boktiar Ahmed Bappy
# 17      Shivananda Sonwane
# 18          Ishawant Kumar
# 19        Deepranjan Gupta
# 20        Shiva Srivastava
# 21             Muskan Garg
# 22             Aditya_iot
# 23      Chaitra K Hiremath
# 24             Rishav Dash
# 25                  Wasim
# 26  Prabir Kumar Satapathy
# 27                Bharath
# 28          Jawala Prakash
# 29           Ayushi Mishra
# 30           Prateek _iot
# 31           Jaydeep Dixit
# 32                Zeeshan
# ...

# %%
df["Total Feedback"].mean()
# Out:
# 12.428187919463086

# %%
question8=((df.groupby("Agent Name")['Total Feedback'].mean())>4.5).count()
question8
# Out:
# 56

# %%
df["Converted Response Time"]=pd.to_datetime(df['Average Response Time'])

# %%
df["Weekly Response Time hour"]=df["Converted Response Time"].dt.hour

# %%
df["Weekly Response Time minute"]=df["Converted Response Time"].dt.minute

# %%
df["Weekly Response Time second"]=df["Converted Response Time"].dt.second

# %%
df["mins"]=df["Weekly Response Time minute"]*60

# %%
df["total time in sec"]=df["mins"]+df["Weekly Response Time second"]

# %%
question9=df.groupby(["Agent Name",'Converted_Date_Week'])["total time in sec"].mean()

# %%
averageweeklyresponse=question9.to_frame()
averageweeklyresponse
# Out:
#                                             total time in sec
# Agent Name             Converted_Date_Week
# Aditya Shinde          26                           83.000000
#                        27                           66.200000
#                        28                           79.000000
# Aditya_iot             27                           70.500000
#                        28                           72.800000
#                        29                           42.200000
#                        30                           60.600000
# Ameya Jain             27                            0.000000
#                        28                           45.600000
#                        29                           41.600000
#                        30                           49.500000
# Anirudh                27                          108.400000
#                        28                           55.500000
# ...

# %%
df["Converted Resolution Time"]=pd.to_datetime(df['Average Resolution Time'])

# %%
df["Weekly Resolution Time in hour" ]=df["Converted Resolution Time"].dt.hour

# %%
df["Weekly Resolution Time in minute" ]=df["Converted Resolution Time"].dt.minute

# %%
df["Weekly Resolution Time in second" ]=df["Converted Resolution Time"].dt.second

# %%
df["hours"]=df["Weekly Resolution Time in hour" ]*3600

# %%
df["minute"]=df["Weekly Resolution Time in minute" ]*60

# %%
df["total time in second"]=df["hours"]+df["minute"]+df["Weekly Resolution Time in second" ]

# %%
question10=df.groupby(["Agent Name",'Converted_Date_Week'])["total time in second"].mean()
weeklyresolution=question10.to_frame()
weeklyresolution
# Out:
#                                             total time in second
# Agent Name             Converted_Date_Week
# Aditya Shinde          26                            1390.500000
#                        27                            1265.400000
#                        28                            1902.200000
# Aditya_iot             27                            1084.500000
#                        28                            1275.400000
#                        29                             941.000000
#                        30                             885.600000
# Ameya Jain             27                             107.000000
#                        28                             677.200000
#                        29                             697.000000
#                        30                             719.250000
# Anirudh                27                             683.000000
#                        28                            1074.500000
# ...

# %%
pd.DataFrame(df["Agent Name"].unique())#question 11
# Out:
#                          0
# 0             Prerna Singh
# 1            Nandani Gupta
# 2               Ameya Jain
# 3            Mahesh Sarade
# 4                   Swati
# 5                  Mukesh
# 6          Saikumarreddy N
# 7            Sanjeev Kumar
# 8           Shubham Sharma
# 9             Nishtha Jain
# 10            Manjunatha A
# 11          Khushboo Priya
# 12           Suraj S Bilgi
# 13      Harikrishnan Shaji
# 14         Hrisikesh Neogi
# 15                Shivan K
# 16       Sowmiya Sivakumar
# 17             Madhulika G
# 18                Mithun S
# 19     Boktiar Ahmed Bappy
# 20      Shivananda Sonwane
# 21          Ishawant Kumar
# 22        Deepranjan Gupta
# 23          Jawala Prakash
# 24        Shiva Srivastava
# 25             Muskan Garg
# 26           Prateek _iot
# 27             Aditya_iot
# 28           Jaydeep Dixit
# 29                Zeeshan
# 30      Chaitra K Hiremath
# 31             Rishav Dash
# 32                  Wasim
# ...

# %%
question12=((df.groupby('Agent Name')['Total Feedback'].sum())/(df.groupby('Agent Name')['Total Chats'].sum()))*100
percentagefeedback=question12.to_frame()
percentagefeedback
# Out:
#                                  0
# Agent Name
# Aditya Shinde            55.234657
# Aditya_iot               56.709957
# Ameya Jain               70.807453
# Anirudh                  48.148148
# Ankitjha                 60.000000
# Anurag Tiwari            75.000000
# Aravind                  63.661202
# Ashad Nasim              50.000000
# Ayushi Mishra            64.007782
# Bharath                  66.937669
# Boktiar Ahmed Bappy      68.805310
# Chaitra K Hiremath       57.812500
# Deepranjan Gupta         63.286004
# Dibyanshu                 0.000000
# Harikrishnan Shaji       60.629921
# Hitesh Choudhary          0.000000
# Hrisikesh Neogi          63.494810
# Ishawant Kumar           59.763314
# Jawala Prakash           56.947608
# Jayant Kumar             55.118110
# Jaydeep Dixit            59.570312
# Khushboo Priya           64.798206
# Madhulika G              59.914712
# Mahak                    71.428571
# Mahesh Sarade            59.340659
# ...

# %%
df1
# Out:
#      SL No                   Agent       Date   Login Time  Logout Time  \
# 0        1      Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM
# 1        2          Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM
# 2        3           Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM
# 3        4         Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM
# 4        5                 Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM
# 5        6       Sowmiya Sivakumar  30-Jul-22  02:03:11 PM  03:05:37 PM
# 6        7            Manjunatha A  30-Jul-22  02:00:12 PM  03:08:29 PM
# 7        8      Harikrishnan Shaji  30-Jul-22  01:53:05 PM  04:06:49 PM
# 8        9           Suraj S Bilgi  30-Jul-22  01:50:01 PM  03:11:42 PM
# 9       10                Shivan K  30-Jul-22  01:28:18 PM  01:59:00 PM
# 10      11           Anurag Tiwari  30-Jul-22  01:06:12 PM  01:11:57 PM
# 11      12          Ishawant Kumar  30-Jul-22  01:05:35 PM  01:12:45 PM
# ...

# %%
df1["update time"]=(pd.to_datetime(df1.Date) + pd.to_timedelta(df1.Duration))

# %%
df1
# Out:
#      SL No                   Agent       Date   Login Time  Logout Time  \
# 0        1      Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM
# 1        2          Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM
# 2        3           Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM
# 3        4         Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM
# 4        5                 Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM
# 5        6       Sowmiya Sivakumar  30-Jul-22  02:03:11 PM  03:05:37 PM
# 6        7            Manjunatha A  30-Jul-22  02:00:12 PM  03:08:29 PM
# 7        8      Harikrishnan Shaji  30-Jul-22  01:53:05 PM  04:06:49 PM
# 8        9           Suraj S Bilgi  30-Jul-22  01:50:01 PM  03:11:42 PM
# 9       10                Shivan K  30-Jul-22  01:28:18 PM  01:59:00 PM
# 10      11           Anurag Tiwari  30-Jul-22  01:06:12 PM  01:11:57 PM
# 11      12          Ishawant Kumar  30-Jul-22  01:05:35 PM  01:12:45 PM
# ...

# %%
df1["update time hours"]=df1["update time"].dt.hour

# %%
df1["update time minute"]=df1["update time"].dt.minute

# %%
df1["update time second"]=df1["update time"].dt.second

# %%
df1["minute"]=df1["update time minute"]*60

# %%
df1["hours"]=df1["update time hours"]*3600

# %%
df1["total time in hour"]=(df1["hours"]+df1["minute"]+df1["update time second"])/3600

# %%
df1['week']=df1['update time'].dt.week
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_15900/3523742363.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df1['week']=df1['update time'].dt.week

# %%
df1
# Out:
#      SL No                   Agent       Date   Login Time  Logout Time  \
# 0        1      Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM
# 1        2          Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM
# 2        3           Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM
# 3        4         Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM
# 4        5                 Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM
# 5        6       Sowmiya Sivakumar  30-Jul-22  02:03:11 PM  03:05:37 PM
# 6        7            Manjunatha A  30-Jul-22  02:00:12 PM  03:08:29 PM
# 7        8      Harikrishnan Shaji  30-Jul-22  01:53:05 PM  04:06:49 PM
# 8        9           Suraj S Bilgi  30-Jul-22  01:50:01 PM  03:11:42 PM
# 9       10                Shivan K  30-Jul-22  01:28:18 PM  01:59:00 PM
# 10      11           Anurag Tiwari  30-Jul-22  01:06:12 PM  01:11:57 PM
# 11      12          Ishawant Kumar  30-Jul-22  01:05:35 PM  01:12:45 PM
# ...

# %%
totalcontributionhour=df1.groupby(['Agent','week'])["total time in hour"].sum()
question13=totalcontributionhour.to_frame() 
question13
# Out:
#                              total time in hour
# Agent                  week
# Aditya Shinde          30              0.036111
# Aditya_iot             29              6.095278
#                        30              9.635833
# Amersh                 30              3.063889
# Ameya Jain             29             24.083056
#                        30             17.992500
# Ankitjha               30              2.266944
# Anurag Tiwari          29              0.264444
#                        30              2.514444
# Aravind                29             24.235556
#                        30              0.063611
# Ayushi Mishra          29             17.790278
#                        30             20.331389
# Bharath                29             24.070833
#                        30             24.005833
# Boktiar Ahmed Bappy    29             17.750278
#                        30             22.518333
# Chaitra K Hiremath     29              2.234722
# ...

# %%
totalcontributionpercentage=((df1.groupby(['Agent'])["total time in hour"].sum())/528)*100
question14=totalcontributionpercentage.to_frame() 
question14
# Out:
#                         total time in hour
# Agent
# Aditya Shinde                     0.006839
# Aditya_iot                        2.979377
# Amersh                            0.580282
# Ameya Jain                        7.968855
# Ankitjha                          0.429346
# Anurag Tiwari                     0.526305
# Aravind                           4.602115
# Ayushi Mishra                     7.220013
# Bharath                           9.105429
# Boktiar Ahmed Bappy               7.626631
# Chaitra K Hiremath                6.501052
# Deepranjan Gupta                 20.127894
# Dibyanshu                         9.961332
# Harikrishnan Shaji               10.173243
# Hrisikesh Neogi                  10.903146
# Hyder Abbas                       0.073495
# Ineuron Intelligence              0.274358
# Ishawant Kumar                    9.806608
# Jawala Prakash                    8.788300
# Jaydeep Dixit                     6.787984
# Khushboo Priya                    8.249737
# ...
